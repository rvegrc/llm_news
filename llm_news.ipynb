# %% [markdown]
# Задача:
# Выполнить оценку работы библиотеки по извлечению текста новости. Необходимо определить полноту извлекаемого текста и оценить значимость тех частей текста, которые выделить не удалось. Проанализировать и предложить изменения в алгоритм работы библиотеки.
#
# Желаемый результат:
# Заполненная таблица -
# с эталоном текста для каждой новости;
# с результатами оценки полноты (сравнения эталона текста и текста, извлеченного библиотекой);
# оценка значимости текста, который выделить не удалось;
# комментарии, если есть предложения по улучшению.

# %%
# 📦 Стандартные библиотеки
import os
import re
from typing import List
from operator import itemgetter

# for .env file support and get access to api keys
from dotenv import load_dotenv
load_dotenv()

# 📦 Сторонние библиотеки
import pandas as pd
from pydantic import BaseModel, Field

# 🚀 LangChain и расширения
from langchain.prompts import PromptTemplate
from langchain_core.prompts import ChatPromptTemplate
from langchain_ollama.llms import OllamaLLM
from langchain.chat_models import ChatOpenAI
from langchain.chains import LLMChain
from langchain_core.output_parsers import StrOutputParser
from langchain.output_parsers import (
    PydanticOutputParser,
    StructuredOutputParser,
    OutputFixingParser,
)
from langchain_community.document_loaders import PyPDFLoader, Docx2txtLoader
from langchain_text_splitters import RecursiveCharacterTextSplitter
from langchain_core.documents import Document
from langchain_core.runnables import (
    Runnable,
    RunnablePassthrough,
    chain,
    RunnableConfig,
)

# 🔎 Graph Retriever
from langchain_graph_retriever import GraphRetriever
from graph_retriever.strategies import Eager
from langchain.schema import Document  # Если нужен именно этот Document
from dotenv import load_dotenv
import glob
from langchain_core.documents import Document
from langchain_huggingface.embeddings import HuggingFaceEmbeddings
from langchain_chroma import Chroma
from langchain_deepseek import ChatDeepSeek

# %%
# import pandas as pd

# from pydantic import BaseModel, Field
# from typing import Dict, Any, List, Optional

# from langchain_core.prompts import PromptTemplate, ChatPromptTemplate
# from langchain_core.output_parsers import PydanticOutputParser, StrOutputParser
# from langchain.output_parsers import OutputFixingParser
# from langchain_core.tools import tool
# from langchain_core.runnables import RunnablePassthrough
# from langchain.agents import initialize_agent, AgentType


# from langchain_huggingface.llms import HuggingFacePipeline
# from transformers import AutoModelForCausalLM, AutoTokenizer, pipeline

# gpu_llm = HuggingFacePipeline.from_model_id(
#     model_id="../models/Mistral-7B-Instruct-v0.3",
#     task="text-generation",
#     pipeline_kwargs={"max_new_tokens": 50},
# )


# cpu_llm = HuggingFacePipeline.from_model_id(
#     model_id="../models/DeepSeek-R1-Distill-Qwen-7B",
#     task="text-generation",
#     pipeline_kwargs={"max_new_tokens": 50},
# )
# Out:
# Loading checkpoint shards:   0%|          | 0/3 [00:00<?, ?it/s]
# Device set to use cpu
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
# Device set to use cpu

# %%
template = """Question: {question}

Answer: Let's think step by step."""
prompt = PromptTemplate.from_template(template)


gpu_chain = prompt | gpu_llm

question = "What is electroencephalography?"

print(gpu_chain.invoke({"question": question}))
# Out:
# Question: What is electroencephalography?
#
# Answer: Let's think step by step.
#
# Electroencephalography (EEG) is a technique used to record the electrical activity of the brain.
#
# Here's a breakdown:
#
# 1. 'Electro': Related to electricity.
#
# 2

# %%
template = """Question: {question}

Answer: Let's think step by step."""
prompt = PromptTemplate.from_template(template)

cpu_chain = prompt | cpu_llm

question = "What is electroencephalography?"

print(cpu_chain.invoke({"question": question}))
# Out:
# Question: What is electroencephalography?
#
# Answer: Let's think step by step. Electroencephalography, or EEG, is a method used to record electrical activity in the brain. It works by placing small sensors, called electrodes, on the scalp. These electrodes detect the electrical signals produced by the brain's neurons as they communicate

# %% [markdown]
# ## Load data

# %%
data_test_web = pd.read_csv("tmp/data_test_web.csv")
data_test_web = data_test_web.dropna(subset=["web_text"]).reset_index(drop=True)
data_test_web.head()
# Out:
#                                                  URL  \
# 0  https://expert.ru/ekonomika/vygodna-li-rossii-...
# 1  https://ria.ru/20250311/klyuchevaya_stavka-196...
# 2  https://expert.ru/mnenie/denis-manturov-gosuda...
# 3    https://ria.ru/20250304/kredity-2003042476.html
# 4           https://lenta.ru/brief/2025/03/11/green/
#
#                                             lib_text  \
# 0  Серьезнее других от введения западных санкций ...
# 1  МОСКВА, 14 фев — РИА Новости Ключевая процентн...
# 2  Со следующего года начнется реализация 12 мега...
# 3  Самозапрет на кредиты - это новая возможность ...
# 4  Заходя в магазин, вы часто замечали зеленые уп...
#
#                                             web_text
# 0  Выгодна ли России отмена санкций США Ослаблени...
# 1  МОСКВА, 25 апр — РИА Новости.Ключевая процентн...
# 2  Денис Мантуров: «Государство в рамках нацпроек...
# 3  МОСКВА, 4 мар - РИА Новости.Самозапрет на кред...
# 4  11:43, 11 марта 2025\nСреда обитания\nКомпании...

# %%
llm = ChatDeepSeek(
    model="deepseek-reasoner",
    temperature=0,
    max_tokens=None,
    timeout=None,
    max_retries=2,
)

# %%
llm.invoke('hello, how are you?')
# Out:
# AIMessage(content="Hello! 😊 I'm doing great—just a digital bundle of energy ready to help you out. How about you? How's your day going? 💬", additional_kwargs={'refusal': None, 'reasoning_content': "Okay, the user just said “hello, how are you?” Such a polite and warm opening! \n\nHmm, they're probably starting a casual conversation. Might be testing the waters or genuinely checking in. Since it's a greeting, they likely expect a friendly but brief response—no deep analysis needed here. \n\nI should match their tone: upbeat but not overbearing. Adding a smile emoji feels right to keep it light. And since they asked about me, I'll bounce the question back to show interest in them too. \n\n...Wait, is this their first message? Maybe they're new. Better keep it extra simple and inviting. No jargon, just approachable. “I'm great” sounds positive without being fake. “How about you?” turns it into a two-way street naturally. \n\nAlso noting zero urgency or frustration in their words—pure neutral vibes. Safe to assume they're in a good mood or at least not distressed. Phew, easy start!"}, response_metadata={'token_usage': {'completion_tokens': 235, 'prompt_tokens': 11, 'total_tokens': 246, 'completion_tokens_details': {'accepted_prediction_tokens': None, 'audio_tokens': None, 'reasoning_tokens': 200, 'rejected_prediction_tokens': None}, 'prompt_tokens_details': {'audio_tokens': None, 'cached_tokens': 0}, 'prompt_cache_hit_tokens': 0, 'prompt_cache_miss_tokens': 11}, 'model_name': 'deepseek-reasoner', 'system_fingerprint': 'fp_393bca965e_prod0425fp8', 'finish_reason': 'stop', 'logprobs': None}, id='run--2f4b83a4-3951-4308-87c8-0c752a40c1ef-0', usage_metadata={'input_tokens': 11, 'output_tokens': 235, 'total_tokens': 246, 'input_token_details': {'cache_read': 0}, 'output_token_details': {'reasoning': 200}})

# %% [markdown]
# ## Простой подход к анализу текста

# %%
class OneComment(BaseModel):
    comment: str = Field(..., description="Выведи комментарий к оценке полноты раскрытия, укажи, что раскрыто полностью, частично или не раскрыто и почему ты так думаешь")
    one_score: str = Field(..., description='''Выведи оценку полноты раскрытия ключевого момента от 0 до 100
                           , где 0 - ключевые моменты отсутствуют и/или не раскрыты, 100 - полностью раскрыты или лучше раскрыты.
                           ''')

class OutputData(BaseModel):
    key_moments: List[OneComment] = Field(..., description="Выведи ключевые моменты раскрытия темы, которые ты будешь оценивать")
    comment: str = Field(..., description="Выведи комментарий к средней оценки полноты раскрытия по всем ключевым моментам")
    overall_score: int = Field(..., description='''Выведи среднюю оценку полноты раскрытия по всем ключевым моментам от 0 до 10
                               , где 0 - ключевые моменты отсутствуют и/или не раскрыты, 100 - полностью раскрыты или лучше раскрыты.
                           ''')

parser = PydanticOutputParser(pydantic_object=OutputData)
parser = OutputFixingParser.from_llm(parser=parser, llm=llm)

# %%
prompt = ChatPromptTemplate.from_template(
    '''
    Выделить ключевые моменты текста {web_text}. Определить наличие этих ключевых моментов и полноту их раскрытия от 0 до 10 в тексте {lib_text}, 
    где 0 - ключевые моменты отсутствуют и/или не раскрыты, 10 - полностью раскрыты или лучше раскрыты.
    Формируй вывод следующим образом:{template}
'''
)

llm_chain = (
    prompt
    | llm 
    | parser
)

result = llm_chain.invoke({
    'template': parser.get_format_instructions(),
    "web_text": data_test_web["web_text"][0],
    "lib_text": data_test_web["lib_text"][0]
})

result
# Out:
# OutputData(key_moments=[OneComment(comment='Уязвимость импортозависимых отраслей (нефтегаз, машиностроение, авиапром) раскрыта полностью: приведены статистика (48.2% в фармацевтике) и примеры компаний.', one_score='10'), OneComment(comment='Переход на китайские технологии в автопроме рассмотрен частично: упомянуты кейсы («АвтоВАЗ»), но отсутствует анализ долгосрочных последствий.', one_score='7'), OneComment(comment='Развитие МСП раскрыто поверхностно: упомянута роль, но нет конкретных механизмов или данных.', one_score='6'), OneComment(comment='Адаптация финансовой инфраструктуры (СПФС, цифровой рубль) описана неполно: глобальные альтернативы SWIFT не проанализированы.', one_score='7'), OneComment(comment='Противоречивые последствия снятия санкций раскрыты хорошо: показаны риски для производителей и исторические прецеденты (Куба, Иран).', one_score='9')], comment='Текст охватывает большинство ключевых аспектов с опорой на данные и примеры, но отдельные моменты (ВПК, долгосрочные прогнозы) требуют детализации.', overall_score=8)

# %% [markdown]
# ## Подход с анализом ключевых моментов и их аспектов

# %%
class AspectOneKeyMoment(BaseModel):
    aspect_key_moment: str = Field(..., description="Выведи аспект ключевого момента")
    aspect_key_moment_comment: str = Field(..., description="Выведи подробный комментарий к аспекту ключевого момента")

class OneKeyMoment(BaseModel):
    # comment: str = Field(..., description="Выведи подробное описанием ключевого момента.")
    one_key_moment: str = Field(..., description='''
                            Выведи ключевой момент.
                           ''')
    all_aspects: List[AspectOneKeyMoment] = Field(..., description="Выведи все аспекты ключевого момента")
    one_key_moment_comment: str = Field(..., description="Выведи комментарий по ключевому моменту")


class AllKeyMoments(BaseModel):
    all_key_moments: List[OneKeyMoment] = Field(..., description="Выведи все ключевые моменты")
    all_key_moments_comment: str = Field(..., description="Выведи комментарий по всем ключевым моментам")


parser = PydanticOutputParser(pydantic_object=AllKeyMoments)
parser = OutputFixingParser.from_llm(parser=parser, llm=llm)

# %%
prompt_key_points = ChatPromptTemplate.from_template(
    '''
    Выделить ключевые моменты текста {web_text} с подробным описанием каждого ключевого момента.
    Отметь подробно все важные аспекты каждого ключевого момента.
    Формируй вывод следующим образом:{template}
'''
)

llm_chain = (
    prompt_key_points
    | llm 
    | parser

)


# web text analyze by key moments and aspects
web_key_moments = []
for text_id in range(len(data_test_web["web_text"][:2])):       
    result = llm_chain.invoke({
        'template': parser.get_format_instructions(),
        "web_text": data_test_web["web_text"][text_id]        
    })
    web_key_moments.append(result)
    print(f"Processed text_id={text_id} of {len(data_test_web['web_text'])}")

# pd.DataFrame(web_key_moments, columns=["all_key_moments", "all_key_moments_comment"]).to_csv("tmp/web_key_moments.csv", index=False)
# Out:
# Processed text_id=0 of 50
# Processed text_id=1 of 50

# %%
web_key_moments
# Out:
# [AllKeyMoments(all_key_moments=[OneKeyMoment(one_key_moment='Отрасли, наиболее пострадавшие от санкций', all_aspects=[AspectOneKeyMoment(aspect_key_moment='Нефтегазовый сектор', aspect_key_moment_comment='Лишился сервисных услуг и западных технологий добычи, что критично для оборудования и технологических процессов.'), AspectOneKeyMoment(aspect_key_moment='Машиностроение и авиастроение', aspect_key_moment_comment='Столкнулись с ограничениями в поставках комплектующих и технологий, особенно в производстве самолетов, кораблей и локомотивов.'), AspectOneKeyMoment(aspect_key_moment='Фармацевтика и химическая промышленность', aspect_key_moment_comment='До 48.2% конечного потребления фармацевтики попало под санкции, создав дефицит критически важной продукции.'), AspectOneKeyMoment(aspect_key_moment='Базовая электроника и IT', aspect_key_moment_comment='Несмотря на эффективное замещение в IT, сохраняется зависимость от иностранных решений в высокотехнологичных сегментах.')], one_key_moment_comment='Санкции сильнее всего ударили по отраслям с высокой импортной зависимостью, где западные технологии и сервисы были незаменимы.'), OneKeyMoment(one_key_moment='Условия отмены санкций США', all_aspects=[AspectOneKeyMoment(aspect_key_moment='Исторические прецеденты', aspect_key_moment_comment='США редко полностью отменяют санкции (примеры: Вьетнам через 25 лет, Куба через 50+ лет, Русал в 2019 г.).'), AspectOneKeyMoment(aspect_key_moment='Требования к отмене', aspect_key_moment_comment='Необходимо изменение ситуации, послужившей причиной санкций, или смена собственников компаний (пример: ОЗОН Банк).'), AspectOneKeyMoment(aspect_key_moment='Политический инструмент', aspect_key_moment_comment='Санкции используются США как рычаг давления для достижения стратегических целей, а не как постоянная мера.'), AspectOneKeyMoment(aspect_key_moment='Секторальный охват', aspect_key_moment_comment='17 секторов экономики России объявлены целями санкций, что усложняет полную отмену ограничений.')], one_key_moment_comment='Отмена возможна лишь при выполнении политических условий США и демонстрации изменений, при этом процесс носит избирательный и фрагментарный характер.'), OneKeyMoment(one_key_moment='Адаптация автопрома', all_aspects=[AspectOneKeyMoment(aspect_key_moment='Переориентация на Китай', aspect_key_moment_comment='АвтоВАЗ, ГАЗ, КамАЗ и другие перешли на сборку китайских моделей (JAC, Chery, Exeed) на своих площадках.'), AspectOneKeyMoment(aspect_key_moment='Инвестиции в импортозамещение', aspect_key_moment_comment='АвтоВАЗ вложил 100+ млрд руб. в замену румынских и турецких поставок, повысив локализацию.'), AspectOneKeyMoment(aspect_key_moment='Риски возврата западных брендов', aspect_key_moment_comment='Эксперты сомневаются в целесообразности возврата Toyota/Hyundai из-за кредитного кризиса (80% продаж в кредит) и новых условий локализации.'), AspectOneKeyMoment(aspect_key_moment='Условия для иностранцев', aspect_key_moment_comment='При возврате западных производителей потребуются запретительные меры: повышенная локализация и гарантии технологического суверенитета.')], one_key_moment_comment='Отрасль перестроилась на китайские платформы, и возврат западных игроков возможен только при жестких условиях, защищающих российские инвестиции.'), OneKeyMoment(one_key_moment='Авиапром: достижения и риски', all_aspects=[AspectOneKeyMoment(aspect_key_moment='Курс на 100% импортозамещение', aspect_key_moment_comment='Разработка отечественных самолетов (поставки ожидаются с 2026 г.) и ПО, инвестиции Аэрофлота в 92 млрд руб. в поддержку флота.'), AspectOneKeyMoment(aspect_key_moment='Стратегическая уязвимость', aspect_key_moment_comment='Снятие санкций может сделать отрасль зависимой от западных технологий, ослабив долгосрочный технологический потенциал.'), AspectOneKeyMoment(aspect_key_moment='Краткосрочные решения', aspect_key_moment_comment='Временный импорт комплектующих допустим для покрытия дефицита, но полный возврат к старой модели признан нецелесообразны ...
#  AllKeyMoments(all_key_moments=[OneKeyMoment(one_key_moment='Текущее значение и решение ЦБ РФ', all_aspects=[AspectOneKeyMoment(aspect_key_moment='Уровень ставки', aspect_key_moment_comment='Ключевая ставка на 25 апреля 2025 года сохранена на уровне 21% годовых. Это решение принято из-за сохраняющегося высокого инфляционного давления.'), AspectOneKeyMoment(aspect_key_moment='Функция ставки', aspect_key_moment_comment='Основной инструмент денежно-кредитной политики для регулирования экономической активности и инфляции. Определяет минимальный процент по кредитам ЦБ для коммерческих банков и ставку по их депозитам.')], one_key_moment_comment='Ставка остаётся на исторически высоком уровне как ответ на инфляционные риски, выполняя роль экономического стабилизатора.'), OneKeyMoment(one_key_moment='Историческая динамика ставки', all_aspects=[AspectOneKeyMoment(aspect_key_moment='Основные вехи', aspect_key_moment_comment='2013: 5.5%; 2014: рост до 17%; 2020: минимум 4.25%; март 2022: пик 20%; 2023: колебания 7.5-12%; 2024: рост до 21%.'), AspectOneKeyMoment(aspect_key_moment='Причины изменений', aspect_key_moment_comment='Реакция на санкции (2022), волатильность валют, инфляционные волны. Повышение в 2022 остановило инфляцию, но ударило по бизнесу.')], one_key_moment_comment='Ставка демонстрирует цикличность, резко реагируя на внешние шоки (санкции) и инфляционные тенденции.'), OneKeyMoment(one_key_moment='Прогнозы на будущее', all_aspects=[AspectOneKeyMoment(aspect_key_moment='Ожидания ЦБ', aspect_key_moment_comment='Средняя ставка в 2025: 17-20%; 2026-2027: снижение до 4%. Целевой уровень инфляции - 4%.'), AspectOneKeyMoment(aspect_key_moment='Факторы влияния', aspect_key_moment_comment='Динамика инфляции, состояние мировой экономики, внутренние условия. Достижение 4% инфляции позволит стабилизировать ставку.')], one_key_moment_comment='ЦБ планирует поэтапное снижение ставки к 2026 году при условии контроля над инфляцией.'), OneKeyMoment(one_key_moment='Процесс установления ставки', all_aspects=[AspectOneKeyMoment(aspect_key_moment='График заседаний', aspect_key_moment_comment='8 заседаний в год в 2025: 14.02, 21.03, 25.04, 06.06, 25.07, 12.09, 24.10, 19.12. Возможны внеплановые собрания.'), AspectOneKeyMoment(aspect_key_moment='Механизм принятия решений', aspect_key_moment_comment='Коллегиальное решение Совета директоров (15 человек во главе с Э. Набиуллиной) на основе анализа десятков параметров: инфляция, рынок труда, кредитование, торговый баланс.')], one_key_moment_comment='Решения принимаются структурированно при комплексной оценке экономики, обеспечивая предсказуемость для рынков.'), OneKeyMoment(one_key_moment='Экономическое влияние', all_aspects=[AspectOneKeyMoment(aspect_key_moment='На инфляцию', aspect_key_moment_comment='Высокая ставка снижает потребительский спрос и кредитование, сдерживая инфляцию. Умеренная инфляция (4%) - целевой ориентир ЦБ для баланса сбережений и инвестиций.'), AspectOneKeyMoment(aspect_key_moment='На кредитный рынок', aspect_key_moment_comment='Рост ставки удорожает кредиты для бизнеса и населения. В 2024: 94% кредитов МСП - оборотные (против 6% инвестиционных), что указывает на отсутствие роста.'), AspectOneKeyMoment(aspect_key_moment='На бизнес', aspect_key_moment_comment='Высокие ставки увеличивают издержки, вынуждая бизнес повышать цены или сокращать инвестиции. Низкие ставки стимулируют расширение производств.'), AspectOneKeyMoment(aspect_key_moment='На фондовый рынок', aspect_key_moment_comment='Рост ставки негативен для акций (растут издержки компаний), но стимулирует выпуск облигаций с плавающим купоном (флоатеры).')], one_key_moment_comment='Ставка выступает главным рычагом воздействия на все сектора экономики, балансируя между сдерживанием инфляции и стимулированием роста.'), OneKeyMoment(one_key_moment='Экспертные оценки', all_aspects=[AspectOneKeyMoment(aspect_key_moment='Поддержка высокой ставки', aspect_key_moment_comment='Артур Мейнхард: ставка необходима для контроля инфляции, сти ...

# %%
class AspectRatio(BaseModel):
    aspect_id: int = Field(..., description="Идентификатор аспекта ключевого момента")
    aspect_ratio_comment: str = Field(..., description="""Сравни тестовый текст по аспекту ключевого момента.
                       Выведи комментарий к сравнению, что раскрыто полностью, частично или не раскрыто и почему ты так думаешь""")
    aspect_ratio: int = Field(..., description='''. 
                       На основании этого сравнения выведи полноту тестового текста 0 до 100, где 0 - аспект не раскрыт, 100 - полностью раскрыт''')
    
class OneKeyMomentRatio(BaseModel):
    all_aspects_ratio: List[AspectRatio] = Field(..., description="Выведи все аспекты ключевого момента с их полнотой раскрытия")
    one_key_moment_ratio_comment: str = Field(..., description="""Сравни тестовый текст по ключевому моменту.
                       Выведи комментарий к сравнению, что раскрыто полностью, частично или не раскрыто и почему ты так думаешь""")
    one_key_moment_ratio: int = Field(..., description='''На основании этого сравнения выведи полноту тестового текста по ключевому моменту от 0 до 100,
                       где 0 - ключевой момент не раскрыт, 100 - полностью раскрыт''')

parser = PydanticOutputParser(pydantic_object=OneKeyMomentRatio)
parser = OutputFixingParser.from_llm(parser=parser, llm=llm)

# %%
# под ключевым моментом понимается ключевой момент вместе с аспектами и их подробным описанием

prompt_ratio = ChatPromptTemplate.from_template(
    '''
    Проверь насколько полно в тестовом тексте: {lib_text}. раскрыт этот ключевой момент: {agg_key_moment}. Определи полноту раскрытия каждого аспекта в отдельности
    и полноту раскрытия ключевого момента как среднее значение по всем аспектам. Ответ выведи в следующем формате: {template}    
'''
)

llm_chain_ratio = (
    prompt_ratio
    | llm
    | parser
 
)

output = []
for text_id, wkm in enumerate(web_key_moments):
    df_key_moments = []

    for target_moment in wkm.all_key_moments:
        agg_key_moment = f'ключевой момент: {target_moment.one_key_moment}\n'
        agg_key_moment += f'комментарий к ключевому моменту: {target_moment.one_key_moment_comment}\n'
        agg_key_moment += 'аспекты ключевого момента:\n\n'
        for n, aspect in enumerate(target_moment.all_aspects):
            agg_key_moment += f'аспект c id={n}: {aspect.aspect_key_moment}\n'
            agg_key_moment += f'комментарий к аспекту c id={n}: {aspect.aspect_key_moment_comment}\n\n'


        result_ratio = llm_chain_ratio.invoke({
            'template': parser.get_format_instructions(),
            "lib_text": data_test_web["lib_text"].iloc[text_id],
            "agg_key_moment": agg_key_moment
        })

        aspects = []
        for aspect in result_ratio.all_aspects_ratio:
            aspects.append({
                    "aspect_id": aspect.aspect_id
                    ,"aspect_name": target_moment.all_aspects[aspect.aspect_id].aspect_key_moment
                    ,"aspect_comment": target_moment.all_aspects[aspect.aspect_id].aspect_key_moment_comment    
                    ,"aspect_ratio": aspect.aspect_ratio
                    ,"aspect_ratio_comment": aspect.aspect_ratio_comment
                })


        df_aspects = pd.DataFrame(aspects)
        df_aspects['key_moment'] = target_moment.one_key_moment
        df_aspects['key_moment_comment'] = target_moment.one_key_moment_comment
        df_aspects['key_moment_ratio'] = result_ratio.one_key_moment_ratio
        df_aspects['key_moment_ratio_comment'] = result_ratio.one_key_moment_ratio_comment

        df_key_moments.append(df_aspects)


    df_key_moments = pd.concat(df_key_moments, ignore_index=True).reset_index(drop=True)

    df_key_moments['text_id'] = text_id

    df_key_moments['text_ratio_mean'] = df_key_moments['key_moment_ratio'].mean()
    df_key_moments['text_ratio_median'] = df_key_moments['key_moment_ratio'].median()

    output.append(df_key_moments)

df_output = pd.concat(output, ignore_index=True).reset_index(drop=True)
df_output.to_csv("tmp/web_key_moments_ratio.csv", index=False)

# %%
df_output
# Out:
#     aspect_id                               aspect_name  \
# 0           0                       Нефтегазовый сектор
# 1           1             Машиностроение и авиастроение
# 2           2  Фармацевтика и химическая промышленность
# 3           3                  Базовая электроника и IT
# 4           0                   Исторические прецеденты
# 5           1                       Требования к отмене
# 6           2                   Политический инструмент
# 7           3                        Секторальный охват
# 8           0                   Переориентация на Китай
# 9           1             Инвестиции в импортозамещение
# 10          2           Риски возврата западных брендов
# 11          3                   Условия для иностранцев
# 12          0             Курс на 100% импортозамещение
# 13          1                 Стратегическая уязвимость
# 14          2                     Краткосрочные решения
# 15          3                       Авиасообщение с США
# 16          0           Укрепление рубля и снижение цен
# 17          1                    Расширение конкуренции
# 18          2                      Доступ к технологиям
# 19          3                    Экспортные перспективы
# 20          0       Угроза отечественным производителям
# 21          1                           Кредитные риски
# 22          2                   Малый бизнес в общепите
# 23          3                     Китайская конкуренция
# 24          0                            Рост числа МСП
# 25          1                         Платежные системы
# 26          2                            Цифровой рубль
# 27          3         Интересы США в финансовом секторе
# 28          0                      Избирательная отмена
# 29          1                    Приоритет безопасности
# 30          2   Добровольное ограничение сотрудничества
# 31          3                 Условия возврата вендоров
# 32          0                            Уровень ставки
# 33          1                            Функция ставки
# 34          0                             Основные вехи
# 35          1                         Причины изменений
# 36          0                               Ожидания ЦБ
# 37          1                           Факторы влияния
# 38          0                          График заседаний
# 39          1                 Механизм принятия решений
# 40          0                               На инфляцию
# 41          1                        На кредитный рынок
# 42          2                                 На бизнес
# 43          3                         На фондовый рынок
# 44          0                  Поддержка высокой ставки
# 45          1                    Критика высокой ставки
# 46          0                     Сравнение со странами
# 47          1                       Глобальное значение
# 48          0                       Официальные ресурсы
# 49          1                              Документация
#
#                                        aspect_comment  aspect_ratio  \
# 0   Лишился сервисных услуг и западных технологий ...            40
# 1   Столкнулись с ограничениями в поставках компле...            95
# 2   До 48.2% конечного потребления фармацевтики по...            35
# 3   Несмотря на эффективное замещение в IT, сохран...            50
# 4   США редко полностью отменяют санкции (примеры:...           100
# 5   Необходимо изменение ситуации, послужившей при...           100
# 6   Санкции используются США как рычаг давления дл...           100
# 7   17 секторов экономики России объявлены целями ...           100
# 8   АвтоВАЗ, ГАЗ, КамАЗ и другие перешли на сборку...           100
# 9   АвтоВАЗ вложил 100+ млрд руб. в замену румынск...           100
# 10  Эксперты сомневаются в целесообразности возвра...            70
# 11  При возврате западных производителей потребуют...           100
# 12  Разработка отечественных самолетов (поставки о...           100
# 13  Снятие санкций может сделать отрасль зависимой...           100
# 14  Временный импорт комплектующих допустим для по...           100
# 15  Не включение большинства авиакомпаний в SDN-ли...           100
# 16  Упрощение логистики удешевит импорт, сделав то...            70
# 17  Возврат западных игроков повысит мотивацию оте...            95
# 18  Упростит получение оборудования для ВПК и стра...            60
# 19  Возобновление экспорта в развитые страны стиму...            40
# 20  Пострадают пищевая промышленность, легкая пром...           100
# 21  Предприятия, взявшие кредиты на импортозамещен...            60
# 22  Возврат сетей вроде Starbucks/McDonald’s удари...           100
# 23  В легкой промышленности китайские производител...           100
# 24  Увеличение с 5.8 млн (2022) до 6.3 млн (2023) ...           100
# 25  СПФС Банка России заменила SWIFT для внутренни...           100
# 26  Пилотный проект ЦБ (2023 г.) может усилить поз...           100
# 27  США заинтересованы в возврате России к долларо...           100
# 28  США вероятно снимут санкции в авиации, металлу...            60
# 29  Экономика адаптировалась к рискам, и резкая от...           100
# 30  Даже при отмене санкций контрагенты могут избе...           100
# 31  В продвинутых отраслях (IT) возврат западных и...           100
# 32  Ключевая ставка на 25 апреля 2025 года сохране...            70
# 33  Основной инструмент денежно-кредитной политики...           100
# 34  2013: 5.5%; 2014: рост до 17%; 2020: минимум 4...           100
# 35  Реакция на санкции (2022), волатильность валют...            75
# 36  Средняя ставка в 2025: 17-20%; 2026-2027: сниж...           100
# 37  Динамика инфляции, состояние мировой экономики...            70
# 38  8 заседаний в год в 2025: 14.02, 21.03, 25.04,...            95
# 39  Коллегиальное решение Совета директоров (15 че...           100
# 40  Высокая ставка снижает потребительский спрос и...           100
# 41  Рост ставки удорожает кредиты для бизнеса и на...           100
# 42  Высокие ставки увеличивают издержки, вынуждая ...           100
# 43  Рост ставки негативен для акций (растут издерж...            70
# 44  Артур Мейнхард: ставка необходима для контроля...           100
# 45  Константин Андрианов: ставка увеличивает издер...           100
# 46  Россия (21%) vs ЕС (3.15%), Турция (50%), Егип...           100
# 47  Решения ФРС и ЕЦБ влияют на мировые рынки. Рос...            60
# 48  Сайт ЦБ (cbr.ru, раздел «Денежно-кредитная пол...           100
# 49  Пресс-релизы публикуются сразу после заседаний...           100
#
#                                  aspect_ratio_comment  \
# 0   Аспект раскрыт частично. Текст подтверждает по...
# 1   Аспект раскрыт полностью. Текст детально анали...
# 2   Аспект раскрыт частично. Текст подтверждает вы...
# 3   Аспект раскрыт частично. Текст отмечает эффект...
# 4   Аспект раскрыт полностью. Текст детально описы...
# 5   Аспект раскрыт полностью. Текст четко формулир...
# 6   Аспект раскрыт полностью. Текст прямо указывае...
# 7   Аспект раскрыт полностью. Текст точно называет...
# 8   Аспект раскрыт полностью. Текст детально описы...
# 9   Аспект раскрыт полностью. Приведена конкретная...
# 10  Аспект раскрыт частично. Текст подтверждает кр...
# 11  Аспект раскрыт полностью. Цитируется позиция Б...
# 12  Аспект раскрыт полностью. Текст содержит детал...
# 13  Аспект раскрыт полностью. Представлен тезис Юр...
# 14  Аспект раскрыт полностью. Мнение Дмитрия Бабан...
# 15  Аспект раскрыт полностью. Упомянуто отсутствие...
# 16  Аспект раскрыт частично. Текст прямо подтвержд...
# 17  Аспект раскрыт полностью. Текст детализирует м...
# 18  Аспект раскрыт частично. Евгений Надоршин упом...
# 19  Аспект раскрыт минимально. Симачев отмечает св...
# 20  Аспект раскрыт полностью. Текст детально описы...
# 21  Аспект раскрыт частично. Текст содержит конкре...
# 22  Аспект раскрыт полностью. Приведена позиция Ал...
# 23  Аспект раскрыт полностью. Детально анализирует...
# 24  Аспект раскрыт полностью. Текст содержит точны...
# 25  Аспект раскрыт полностью. Текст объясняет функ...
# 26  Аспект раскрыт полностью. Текст сообщает о пил...
# 27  Аспект раскрыт полностью. Текст прямо цитирует...
# 28  Аспект раскрыт частично. В тексте есть упомина...
# 29  Аспект раскрыт полностью. Текст содержит прямы...
# 30  Аспект раскрыт полностью. Евгений Надоршин дет...
# 31  Аспект раскрыт полностью. Юрий Симачев прямо у...
# 32  Аспект раскрыт частично. В тексте явно указано...
# 33  Аспект раскрыт полностью. Текст детально объяс...
# 34  Аспект раскрыт полностью. Текст содержит детал...
# 35  Аспект раскрыт частично. Текст полно объясняет...
# 36  Аспект раскрыт полностью. В тексте прямо указа...
# 37  Аспект раскрыт частично. Текст перечисляет осн...
# 38  Текст полностью раскрывает график заседаний: у...
# 39  Текст исчерпывающе раскрывает механизм приняти...
# 40  Аспект раскрыт полностью. Текст детально объяс...
# 41  Аспект раскрыт полностью. Текст содержит пряму...
# 42  Аспект раскрыт полностью. Текст детализирует в...
# 43  Аспект раскрыт частично. Текст объясняет негат...
# 44  Аспект 'Поддержка высокой ставки' раскрыт полн...
# 45  Аспект 'Критика высокой ставки' раскрыт полнос...
# 46  Аспект раскрыт полностью. В тексте представлен...
# 47  Аспект раскрыт частично. Текст упоминает монит...
# 48  Аспект раскрыт полностью. В тексте явно указан...
# 49  Аспект раскрыт полностью. Текст детально описы...
#
#                                      key_moment  \
# 0     Отрасли, наиболее пострадавшие от санкций
# 1     Отрасли, наиболее пострадавшие от санкций
# 2     Отрасли, наиболее пострадавшие от санкций
# 3     Отрасли, наиболее пострадавшие от санкций
# 4                    Условия отмены санкций США
# 5                    Условия отмены санкций США
# 6                    Условия отмены санкций США
# 7                    Условия отмены санкций США
# 8                           Адаптация автопрома
# 9                           Адаптация автопрома
# 10                          Адаптация автопрома
# 11                          Адаптация автопрома
# 12                 Авиапром: достижения и риски
# 13                 Авиапром: достижения и риски
# 14                 Авиапром: достижения и риски
# 15                 Авиапром: достижения и риски
# 16            Позитивные эффекты отмены санкций
# 17            Позитивные эффекты отмены санкций
# 18            Позитивные эффекты отмены санкций
# 19            Позитивные эффекты отмены санкций
# 20  Негативные последствия для импортозамещения
# 21  Негативные последствия для импортозамещения
# 22  Негативные последствия для импортозамещения
# 23  Негативные последствия для импортозамещения
# 24               Роль МСП и системные изменения
# 25               Роль МСП и системные изменения
# 26               Роль МСП и системные изменения
# 27               Роль МСП и системные изменения
# 28                 Экспертные оценки перспектив
# 29                 Экспертные оценки перспектив
# 30                 Экспертные оценки перспектив
# 31                 Экспертные оценки перспектив
# 32             Текущее значение и решение ЦБ РФ
# 33             Текущее значение и решение ЦБ РФ
# 34                 Историческая динамика ставки
# 35                 Историческая динамика ставки
# 36                          Прогнозы на будущее
# 37                          Прогнозы на будущее
# 38                  Процесс установления ставки
# 39                  Процесс установления ставки
# 40                        Экономическое влияние
# 41                        Экономическое влияние
# 42                        Экономическое влияние
# 43                        Экономическое влияние
# 44                            Экспертные оценки
# 45                            Экспертные оценки
# 46                       Международный контекст
# 47                       Международный контекст
# 48                         Источники информации
# 49                         Источники информации
#
#                                    key_moment_comment  key_moment_ratio  \
# 0   Санкции сильнее всего ударили по отраслям с вы...                55
# 1   Санкции сильнее всего ударили по отраслям с вы...                55
# 2   Санкции сильнее всего ударили по отраслям с вы...                55
# 3   Санкции сильнее всего ударили по отраслям с вы...                55
# 4   Отмена возможна лишь при выполнении политическ...               100
# 5   Отмена возможна лишь при выполнении политическ...               100
# 6   Отмена возможна лишь при выполнении политическ...               100
# 7   Отмена возможна лишь при выполнении политическ...               100
# 8   Отрасль перестроилась на китайские платформы, ...                93
# 9   Отрасль перестроилась на китайские платформы, ...                93
# 10  Отрасль перестроилась на китайские платформы, ...                93
# 11  Отрасль перестроилась на китайские платформы, ...                93
# 12  Отрасль добилась прогресса в импортозамещении,...               100
# 13  Отрасль добилась прогресса в импортозамещении,...               100
# 14  Отрасль добилась прогресса в импортозамещении,...               100
# 15  Отрасль добилась прогресса в импортозамещении,...               100
# 16  Отмена санкций может дать импульс экономике че...                66
# 17  Отмена санкций может дать импульс экономике че...                66
# 18  Отмена санкций может дать импульс экономике че...                66
# 19  Отмена санкций может дать импульс экономике че...                66
# 20  Ослабление санкций ставит под удар достижения ...                90
# 21  Ослабление санкций ставит под удар достижения ...                90
# 22  Ослабление санкций ставит под удар достижения ...                90
# 23  Ослабление санкций ставит под удар достижения ...                90
# 24  МСП стали драйвером адаптации, а создание СПФС...               100
# 25  МСП стали драйвером адаптации, а создание СПФС...               100
# 26  МСП стали драйвером адаптации, а создание СПФС...               100
# 27  МСП стали драйвером адаптации, а создание СПФС...               100
# 28  Эксперты считают отмену санкций вероятной лишь...                90
# 29  Эксперты считают отмену санкций вероятной лишь...                90
# 30  Эксперты считают отмену санкций вероятной лишь...                90
# 31  Эксперты считают отмену санкций вероятной лишь...                90
# 32  Ставка остаётся на исторически высоком уровне ...                85
# 33  Ставка остаётся на исторически высоком уровне ...                85
# 34  Ставка демонстрирует цикличность, резко реагир...                88
# 35  Ставка демонстрирует цикличность, резко реагир...                88
# 36  ЦБ планирует поэтапное снижение ставки к 2026 ...                85
# 37  ЦБ планирует поэтапное снижение ставки к 2026 ...                85
# 38  Решения принимаются структурированно при компл...                98
# 39  Решения принимаются структурированно при компл...                98
# 40  Ставка выступает главным рычагом воздействия н...                93
# 41  Ставка выступает главным рычагом воздействия н...                93
# 42  Ставка выступает главным рычагом воздействия н...                93
# 43  Ставка выступает главным рычагом воздействия н...                93
# 44  Эксперты разделились: одни видят в высокой ста...               100
# 45  Эксперты разделились: одни видят в высокой ста...               100
# 46  Ставка в РФ находится на верхней границе миров...                80
# 47  Ставка в РФ находится на верхней границе миров...                80
# 48  ЦБ обеспечивает прозрачность данных, оперативн...               100
# 49  ЦБ обеспечивает прозрачность данных, оперативн...               100
#
#                              key_moment_ratio_comment  text_id  \
# 0   Ключевой момент раскрыт частично (55/100). Тек...        0
# 1   Ключевой момент раскрыт частично (55/100). Тек...        0
# 2   Ключевой момент раскрыт частично (55/100). Тек...        0
# 3   Ключевой момент раскрыт частично (55/100). Тек...        0
# 4   Ключевой момент раскрыт полностью. Текст детал...        0
# 5   Ключевой момент раскрыт полностью. Текст детал...        0
# 6   Ключевой момент раскрыт полностью. Текст детал...        0
# 7   Ключевой момент раскрыт полностью. Текст детал...        0
# 8   Ключевой момент раскрыт почти полностью. Детал...        0
# 9   Ключевой момент раскрыт почти полностью. Детал...        0
# 10  Ключевой момент раскрыт почти полностью. Детал...        0
# 11  Ключевой момент раскрыт почти полностью. Детал...        0
# 12  Ключевой момент раскрыт полностью. Текст детал...        0
# 13  Ключевой момент раскрыт полностью. Текст детал...        0
# 14  Ключевой момент раскрыт полностью. Текст детал...        0
# 15  Ключевой момент раскрыт полностью. Текст детал...        0
# 16  Ключевой момент раскрыт частично (66%). Текст ...        0
# 17  Ключевой момент раскрыт частично (66%). Текст ...        0
# 18  Ключевой момент раскрыт частично (66%). Текст ...        0
# 19  Ключевой момент раскрыт частично (66%). Текст ...        0
# 20  Ключевой момент раскрыт полно. Текст системно ...        0
# 21  Ключевой момент раскрыт полно. Текст системно ...        0
# 22  Ключевой момент раскрыт полно. Текст системно ...        0
# 23  Ключевой момент раскрыт полно. Текст системно ...        0
# 24  Ключевой момент раскрыт полностью. Текст детал...        0
# 25  Ключевой момент раскрыт полностью. Текст детал...        0
# 26  Ключевой момент раскрыт полностью. Текст детал...        0
# 27  Ключевой момент раскрыт полностью. Текст детал...        0
# 28  Ключевой момент раскрыт почти полностью. Экспе...        0
# 29  Ключевой момент раскрыт почти полностью. Экспе...        0
# 30  Ключевой момент раскрыт почти полностью. Экспе...        0
# 31  Ключевой момент раскрыт почти полностью. Экспе...        0
# 32  Ключевой момент раскрыт частично. Текст полно ...        1
# 33  Ключевой момент раскрыт частично. Текст полно ...        1
# 34  Ключевой момент раскрыт полно, но с дисбалансо...        1
# 35  Ключевой момент раскрыт полно, но с дисбалансо...        1
# 36  Ключевой момент раскрыт полно, но с неравномер...        1
# 37  Ключевой момент раскрыт полно, но с неравномер...        1
# 38  Текст полностью раскрывает процесс установлени...        1
# 39  Текст полностью раскрывает процесс установлени...        1
# 40  Ключевой момент раскрыт почти полностью. Текст...        1
# 41  Ключевой момент раскрыт почти полностью. Текст...        1
# 42  Ключевой момент раскрыт почти полностью. Текст...        1
# 43  Ключевой момент раскрыт почти полностью. Текст...        1
# 44  Ключевой момент 'Экспертные оценки' раскрыт ис...        1
# 45  Ключевой момент 'Экспертные оценки' раскрыт ис...        1
# 46  Ключевой момент раскрыт на среднем уровне. Сра...        1
# 47  Ключевой момент раскрыт на среднем уровне. Сра...        1
# 48  Ключевой момент раскрыт полностью. Текст содер...        1
# 49  Ключевой момент раскрыт полностью. Текст содер...        1
#
#     text_ratio_mean  text_ratio_median
# 0         86.750000               91.5
# 1         86.750000               91.5
# 2         86.750000               91.5
# 3         86.750000               91.5
# 4         86.750000               91.5
# 5         86.750000               91.5
# 6         86.750000               91.5
# 7         86.750000               91.5
# 8         86.750000               91.5
# 9         86.750000               91.5
# 10        86.750000               91.5
# 11        86.750000               91.5
# 12        86.750000               91.5
# 13        86.750000               91.5
# 14        86.750000               91.5
# 15        86.750000               91.5
# 16        86.750000               91.5
# 17        86.750000               91.5
# 18        86.750000               91.5
# 19        86.750000               91.5
# 20        86.750000               91.5
# 21        86.750000               91.5
# 22        86.750000               91.5
# 23        86.750000               91.5
# 24        86.750000               91.5
# 25        86.750000               91.5
# 26        86.750000               91.5
# 27        86.750000               91.5
# 28        86.750000               91.5
# 29        86.750000               91.5
# 30        86.750000               91.5
# 31        86.750000               91.5
# 32        91.333333               93.0
# 33        91.333333               93.0
# 34        91.333333               93.0
# 35        91.333333               93.0
# 36        91.333333               93.0
# 37        91.333333               93.0
# 38        91.333333               93.0
# 39        91.333333               93.0
# 40        91.333333               93.0
# 41        91.333333               93.0
# 42        91.333333               93.0
# 43        91.333333               93.0
# 44        91.333333               93.0
# 45        91.333333               93.0
# 46        91.333333               93.0
# 47        91.333333               93.0
# 48        91.333333               93.0
# 49        91.333333               93.0

# %%
data_test_web['text_id'] = data_test_web.index
df_output_group_id = df_output.groupby('text_id').agg({
    'text_ratio_mean': 'mean',
    'text_ratio_median': 'median'
}).reset_index()
data_test_web = data_test_web.merge(df_output_group_id, on='text_id', how='left')

data_test_web
# Out:
#                                                   URL  \
# 0   https://expert.ru/ekonomika/vygodna-li-rossii-...
# 1   https://ria.ru/20250311/klyuchevaya_stavka-196...
# 2   https://expert.ru/mnenie/denis-manturov-gosuda...
# 3     https://ria.ru/20250304/kredity-2003042476.html
# 4            https://lenta.ru/brief/2025/03/11/green/
# 5         https://lenta.ru/articles/2025/03/09/aslan/
# 6   https://expert.ru/finance/investorov-svyazyvay...
# 7         https://ria.ru/20250123/svo-1985822676.html
# 8   https://expert.ru/mnenie/vse-teper-zavisit-tol...
# 9       https://ria.ru/docs/about/privacy_policy.html
# 10  https://ria.ru/docs/about/privacy_policy.html#...
# 11  https://lenta.ru/extlink/2025/03/10/na-ukraine...
# 12  https://lenta.ru/news/2025/03/10/na-ukraine-is...
# 13  https://expert.ru/news/rynok-onlayn-torgovli-v...
# 14  https://lenta.ru/extlink/2025/03/10/rossiyu-oz...
# 15               https://www.vesti.ru/article/4393501
# 16               https://www.vesti.ru/article/4371632
# 17        https://lenta.ru/articles/2025/03/10/davka/
# 18         https://ria.ru/20250310/es-2003634059.html
# 19     https://ria.ru/20250109/nalogi-1949044822.html
# 20     https://ria.ru/20250311/siriya-2004136885.html
# 21  https://expert.ru/mnenie/dmitriy-chernyshenko-...
# 22     https://ria.ru/20250116/vychet-1732389458.html
# 23      https://lenta.ru/articles/2025/02/20/maresev/
# 24             https://www.vesti.ru/article/4377312-1
# 25  https://expert.ru/news/banki-i-mfo-zafiksirova...
# 26  https://expert.ru/news/baltika-i-mpk-soobshchi...
# 27  https://ria.ru/20250311/gorbachev-2004161660.html
# 28  https://lenta.ru/articles/2025/03/10/aleksandr-3/
# 29  https://lenta.ru/extlink/2025/03/10/putin-kont...
# 30           https://lenta.ru/news/2025/03/10/europe/
# 31  https://expert.ru/ekonomika/maksim-reshetnikov...
# 32     https://ria.ru/20250310/kallas-2003924425.html
# 33    https://ria.ru/20241220/shtrafy-1990507458.html
# 34  https://expert.ru/finance/eksportery-sbrosili-...
# 35  https://expert.ru/news/banki-ssha-speshat-zapu...
# 36     https://ria.ru/20250311/vojska-2004271868.html
# 37  https://expert.ru/mnenie/maksim-reshetnikov-ni...
# 38   https://ria.ru/20250310/poshliny-2003708178.html
# 39  https://expert.ru/news/amerikanskie-startapy-p...
# 40  https://expert.ru/v-mire/voyna-eshche-ne-zakon...
# 41  https://expert.ru/multimedia/photos/v-moskve-p...
# 42  https://ria.ru/20250311/pridnestrove-200421351...
# 43  https://expert.ru/news/minstroy-rekomendoval-n...
# 44  https://expert.ru/v-mire/amerika-ispytyvaet-kr...
# 45  https://expert.ru/novosti-partnerov/transforma...
# 46  https://ria.ru/20250311/matkapital-1733022511....
# 47  https://lenta.ru/news/2025/03/10/odin-iz-samyh...
# 48     https://ria.ru/20250311/aktivy-2004213012.html
# 49  https://expert.ru/news/roskomnadzor-soobshchil...
#
#                                              lib_text  \
# 0   Серьезнее других от введения западных санкций ...
# 1   МОСКВА, 14 фев — РИА Новости Ключевая процентн...
# 2   Со следующего года начнется реализация 12 мега...
# 3   Самозапрет на кредиты - это новая возможность ...
# 4   Заходя в магазин, вы часто замечали зеленые уп...
# 5   20 лет назад, 8 марта 2005 года, в чеченском с...
# 6   Говоря сухим языком определений, цифровые фина...
# 7   Поддержка военнослужащих и их семей с самого н...
# 8   — За последние два с половиной года из-за введ...
# 9   Федеральное государственное унитарное предприя...
# 10  Федеральное государственное унитарное предприя...
# 11  Основатель компании SpaceX Илон Маск заявил, ч...
# 12  Основатель компании SpaceX Илон Маск заявил, ч...
# 13  По данным INFOLine, на e-com в 2024 году пришл...
# 14  2025 год может стать для России годом «увольне...
# 15  Сегодня мы рассказываем о полуторагодовалой Ле...
# 16  Сегодня мы рассказываем о 14-летней Ксюше Коно...
# 17  00:01, 10 марта 2025Фото: Игорь Уткин / ТАСС10...
# 18  МОСКВА, 6 мар — РИА Новости, Михаил Катков. Ев...
# 19  МОСКВА, 9 янв — РИА Новости, Надежда Сарапина....
# 20  МОСКВА, 11 мар — РИА Новости, Михаил Катков. В...
# 21  — Вы курируете в том числе и Минпросвещения. К...
# 22  МОСКВА, 16 янв — РИА Новости. Налоговый вычет ...
# 23  12:19, 20 февраля 2025Для нескольких поколений...
# 24  В 2025 году вся Россия празднует 8 Марта — Меж...
# 25  По данным МФО «Займер», каждый день компания п...
# 26  «Балтика» уведомила торговые сети о том, что о...
# 27  МОСКВА, 11 мар — РИА Новости, Виктор Жданов. С...
# 28  180 лет назад, 10 марта 1845 года, родился имп...
# 29  Личность болгарской ясновидящей Ванги окутана ...
# 30  Все больше российских туристов предпочитают от...
# 31  — Термин «импортозамещение» как будто начал вы...
# 32  В Европе в самом разгаре ожесточенная избирате...
# 33  МОСКВА, 20 дек — РИА Новости. Штрафы ГИБДД за ...
# 34  Российские экспортеры в феврале 2025 г. реализ...
# 35  Bank of America планирует выпустить собственну...
# 36  КУРСК, 11 мар — РИА Новости. Российские войска...
# 37  — С чем Россия приехала на климатическую конфе...
# 38  МОСКВА, 10 мар — РИА Новости, Надежда Сарапина...
# 39  Уточняется, что в последнем квартале прошлого ...
# 40  «Сирию могут расчленить»\nВедущий научный сотр...
# 41  На NAIS был впервые показан широкой публике от...
# 42  Последние события в Румынии, включающие фактич...
# 43  В Минстрое уточнили, что документ носит рекоме...
# 44  Победа на выборах Дональда Трампа и разговоры ...
# 45  Цель проекта — «разработать универсальную диза...
# 46  МОСКВА, 12 мар - РИА Новости. Материнский капи...
# 47  Российские войска начали реализацию одного из ...
# 48  МОСКВА, 11 мар — РИА Новости. Должностные лица...
# 49  Составлено пять протоколов об административном...
#
#                                              web_text  text_id  \
# 0   Выгодна ли России отмена санкций США Ослаблени...        0
# 1   МОСКВА, 25 апр — РИА Новости.Ключевая процентн...        1
# 2   Денис Мантуров: «Государство в рамках нацпроек...        2
# 3   МОСКВА, 4 мар - РИА Новости.Самозапрет на кред...        3
# 4   11:43, 11 марта 2025\nСреда обитания\nКомпании...        4
# 5   Date: 00:01, 9 марта 2025\nCategory: Силовые с...        5
# 6   Инвесторов связывают блокчейном Как ЦФА меняют...        6
# 7   МОСКВА, 23 янв - РИА Новости.Выплаты участника...        7
# 8   Геннадий Красников: «У нас остались школы, дос...        8
# 9   Федеральное государственное унитарное предприя...        9
# 10  Федеральное государственное унитарное предприя...       10
# 11  Date: 20:14, 10 марта 2025\nCategory: Наука и ...       11
# 12  Date: 20:14, 10 марта 2025\nCategory: Наука и ...       12
# 13  Рынок онлайн-торговли в России за год вырос на...       13
# 14  Date: 00:03, 8 марта 2025\nCategory: Экономика...       14
# 15  10 марта 2025\n09:00\nНужна помощь: Леру Смирн...       15
# 16  24 февраля 2025\n09:00\nНужна помощь: Ксюшу Ко...       16
# 17  Title: «Мне было страшно на это смотреть» 50 л...       17
# 18  МОСКВА, 6 мар — РИА Новости, Михаил Катков.Евр...       18
# 19  МОСКВА, 9 янв — РИА Новости, Надежда Сарапина....       19
# 20  МОСКВА, 11 мар — РИА Новости, Михаил Катков.В ...       20
# 21  Дмитрий Чернышенко: «Карьера в науке должна ст...       21
# 22  МОСКВА, 16 янв — РИА Новости.Налоговый вычет —...       22
# 23  Title: «У фрицев есть передо мной должок» Как ...       23
# 24  03 марта 2025\n12:15\nПраздники в марте 2025 г...       24
# 25  Банки и МФО зафиксировали попытки обойти самоз...       25
# 26  Производители пива уведомили ретейлеров о повы...       26
# 27  МОСКВА, 11 мар — РИА Новости, Виктор Жданов.Су...       27
# 28  Date: 00:01, 10 марта 2025\nCategory: Наука и ...       28
# 29  Date: 00:01, 9 марта 2025\nCategory: Интернет ...       29
# 30  Date: 21:03, 10 марта 2025\nCategory: Путешест...       30
# 31  Максим Решетников: «Есть два направления работ...       31
# 32  В Европе в самом разгаре ожесточенная избирате...       32
# 33  МОСКВА, 1 апр — РИА Новости.Штрафы ГИБДД за на...       33
# 34  Экспортеры сбросили валюту Население скупает д...       34
# 35  FT: Банки США спешат запустить криптовалюты 20...       35
# 36  КУРСК, 11 мар — РИА Новости.Российские войска ...       36
# 37  Максим Решетников: «Низкоуглеродная трансформа...       37
# 38  МОСКВА, 10 мар — РИА Новости, Надежда Сарапина...       38
# 39  Американские стартапы привлекли максимум инвес...       39
# 40  Война еще не закончилась К чему приведет крово...       40
# 41  7 февраля 2025\nВ Москве прошла выставка инфра...       41
# 42  Последние события в Румынии, включающие фактич...       42
# 43  Минстрой рекомендовал не строить микроквартиры...       43
# 44  Америка испытывает крипторынок на прочность На...       44
# 45  Трансформация образа: в чем ценность дизайн-си...       45
# 46  МОСКВА, 12 мар - РИА Новости.Материнский капит...       46
# 47  Date: 14:07, 10 марта 2025\nCategory: Россия\n...       47
# 48  МОСКВА, 11 мар — РИА Новости.Должностные лица ...       48
# 49  Роскомнадзор сообщил о 19 утечках данных росси...       49
#
#     text_ratio_mean  text_ratio_median
# 0         86.750000               91.5
# 1         91.333333               93.0
# 2               NaN                NaN
# 3               NaN                NaN
# 4               NaN                NaN
# 5               NaN                NaN
# 6               NaN                NaN
# 7               NaN                NaN
# 8               NaN                NaN
# 9               NaN                NaN
# 10              NaN                NaN
# 11              NaN                NaN
# 12              NaN                NaN
# 13              NaN                NaN
# 14              NaN                NaN
# 15              NaN                NaN
# 16              NaN                NaN
# 17              NaN                NaN
# 18              NaN                NaN
# 19              NaN                NaN
# 20              NaN                NaN
# 21              NaN                NaN
# 22              NaN                NaN
# 23              NaN                NaN
# 24              NaN                NaN
# 25              NaN                NaN
# 26              NaN                NaN
# 27              NaN                NaN
# 28              NaN                NaN
# 29              NaN                NaN
# 30              NaN                NaN
# 31              NaN                NaN
# 32              NaN                NaN
# 33              NaN                NaN
# 34              NaN                NaN
# 35              NaN                NaN
# 36              NaN                NaN
# 37              NaN                NaN
# 38              NaN                NaN
# 39              NaN                NaN
# 40              NaN                NaN
# 41              NaN                NaN
# 42              NaN                NaN
# 43              NaN                NaN
# 44              NaN                NaN
# 45              NaN                NaN
# 46              NaN                NaN
# 47              NaN                NaN
# 48              NaN                NaN
# 49              NaN                NaN

# %%
data_test_web = pd.read_csv("tmp/data_test_web.csv")
data_test_web.head()
# Out:
#                                                  URL  \
# 0  https://expert.ru/ekonomika/vygodna-li-rossii-...
# 1  https://ria.ru/20250311/klyuchevaya_stavka-196...
# 2  https://expert.ru/mnenie/denis-manturov-gosuda...
# 3    https://ria.ru/20250304/kredity-2003042476.html
# 4           https://lenta.ru/brief/2025/03/11/green/
#
#                                             lib_text  \
# 0  Серьезнее других от введения западных санкций ...
# 1  МОСКВА, 14 фев — РИА Новости Ключевая процентн...
# 2  Со следующего года начнется реализация 12 мега...
# 3  Самозапрет на кредиты - это новая возможность ...
# 4  Заходя в магазин, вы часто замечали зеленые уп...
#
#                                             web_text
# 0  Выгодна ли России отмена санкций США Ослаблени...
# 1  МОСКВА, 25 апр — РИА Новости.Ключевая процентн...
# 2  Денис Мантуров: «Государство в рамках нацпроек...
# 3  МОСКВА, 4 мар - РИА Новости.Самозапрет на кред...
# 4  11:43, 11 марта 2025\nСреда обитания\nКомпании...

# %%
result_ratio
# Out:
# OneKeyMomentRatio(all_aspects_ratio=[AspectRatio(aspect_id=0, aspect_ratio_comment='Аспект раскрыт почти полностью. В тексте детально перечислены пострадавшие отрасли (нефтегаз, машиностроение, авиапром, фармацевтика, электроника и IT), приведены примеры ограничений (сервисные услуги, технологии добычи), механизмы адаптации (переход на китайские платформы в автопроме, рост МСП в легкой промышленности). Однако электроника и IT упомянуты кратко, без конкретных примеров замещения.', aspect_ratio=85), AspectRatio(aspect_id=1, aspect_ratio_comment='Аспект раскрыт частично. Цифры из прогноза ЦМАКП (48.2% для фармацевтики, 44.7% для химической промышленности, 32.2% для авиастроения) приведены, но отсутствует анализ их актуальности на текущий момент. Нет сравнения с реальными последствиями санкций после 2022 г., что снижает глубину раскрытия.', aspect_ratio=70)], one_key_moment_ratio_comment='Ключевой момент раскрыт полно, но с некоторыми пробелами. Текст подтверждает тезис о стимулировании импортозамещения (примеры с автопромом, IT, легкой промышленностью) и проблемах в станкостроении/судостроении (упоминание о незавершенности процессов). Однако детали по станкостроению ограничены общими фразами, а примеры судостроения практически отсутствуют. Акцент смещен на успешные кейсы, тогда как проблемные отрасли рассмотрены менее системно.', one_key_moment_ratio=78)

# %%
df_key_moments

# %%
result.all_key_moments
# Out:
# [OneKeyMoment(one_key_moment='Влияние санкций на ключевые отрасли экономики России', all_aspects=[AspectOneKeyMoment(aspect_key_moment='Наиболее пострадавшие отрасли', aspect_key_moment_comment='Нефтегазовый сектор, машиностроение, авиастроение, фармацевтика, электроника и IT. Санкции ограничили доступ к технологиям и сервисам, что привело к необходимости импортозамещения.'), AspectOneKeyMoment(aspect_key_moment='Прогнозы аналитиков ЦМАКП', aspect_key_moment_comment='В марте 2022 г. прогнозировалось наибольшее влияние на фармацевтику (48.2%), химическую промышленность (44.7%) и авиастроение (32.2%).')], one_key_moment_comment='Санкции стимулировали развитие отечественного производства, но в ряде отраслей (станкостроение, судостроение) замещение импорта остается незавершенным.'),
#  OneKeyMoment(one_key_moment='Сценарии снятия санкций США', all_aspects=[AspectOneKeyMoment(aspect_key_moment='Условия отмены', aspect_key_moment_comment='США снимают санкции только при достижении целей их введения или смене собственников компаний (пример: «Русал» и «ОЗОН Банк»).'), AspectOneKeyMoment(aspect_key_moment='Политическая мотивация', aspect_key_moment_comment='Санкции — инструмент давления. Их смягчение возможно для укрепления позиций США, как в случае с авиацией и долларовыми расчетами.')], one_key_moment_comment='Полная отмена маловероятна; возможны точечные послабления в секторах, выгодных США (металлургия, энергетика).'),
#  OneKeyMoment(one_key_moment='Трансформация автопрома', all_aspects=[AspectOneKeyMoment(aspect_key_moment='Переход на китайские платформы', aspect_key_moment_comment='Заводы в Калининграде, Москве и Калуге перешли на сборку китайских марок (JAC, Chery, Exeed).'), AspectOneKeyMoment(aspect_key_moment='Риски возврата западных брендов', aspect_key_moment_comment='Возврат иностранных производителей потребует ужесточения условий локализации для защиты технологического суверенитета.')], one_key_moment_comment='Рынок авто стагнирует из-за высоких кредитных нагрузок и утильсбора, что снижает привлекательность для иностранных компаний.'),
#  OneKeyMoment(one_key_moment='Авиапром и импортозамещение', all_aspects=[AspectOneKeyMoment(aspect_key_moment='100% локализация', aspect_key_moment_comment='Планы по выпуску отечественных самолетов к 2026 г., но задержки связаны с технологическими вызовами.'), AspectOneKeyMoment(aspect_key_moment='Санкционные риски', aspect_key_moment_comment='США могут смягчить санкции в обмен на уступки, но это угрожает долгосрочной зависимости от западных технологий.')], one_key_moment_comment='Авиакомпании инвестируют в российское ПО и запчасти («Аэрофлот» — 92 млрд руб. в 2024 г.), что снижает уязвимость.'),
#  OneKeyMoment(one_key_moment='Роль МСП в импортозамещении', all_aspects=[AspectOneKeyMoment(aspect_key_moment='Рост числа предприятий', aspect_key_moment_comment='С 5.8 млн (2022 г.) до 6.3 млн (2023 г.) — малый бизнес быстро адаптируется к санкциям.'), AspectOneKeyMoment(aspect_key_moment='Китайская конкуренция', aspect_key_moment_comment='В легкой промышленности китайские производители вытесняют российские (пример: закрытие Gloria Jeans).')], one_key_moment_comment='МСП стали драйвером замещения, но зависимость от китайских поставок сохраняется.'),
#  OneKeyMoment(one_key_moment='Финансовая инфраструктура', all_aspects=[AspectOneKeyMoment(aspect_key_moment='СПФС vs SWIFT', aspect_key_moment_comment='Российская система охватывает внутренние платежи, но не конкурирует глобально, в отличие от китайской CIPS.'), AspectOneKeyMoment(aspect_key_moment='Цифровой рубль', aspect_key_moment_comment='Пилотный проект ЦБ заморожен из-за запросов участников; массовое внедрение отложено.')], one_key_moment_comment='Отмена санкций не восстановит доступ к SWIFT, но усилит роль альтернативных систем.')]

# %%
rows = []
for n, item in enumerate(result.all_key_moments):
    for aspect in item.all_aspects:
        rows.append({
            'key_moment_id': n,
            "key_moment": item.one_key_moment,
            "key_moment_comment": item.one_key_moment_comment,
            "aspect": aspect.aspect_key_moment,
            "aspect_comment": aspect.aspect_key_moment_comment
        })

df = pd.DataFrame(rows)

df
# Out:
#     key_moment_id                                         key_moment  \
# 0               0  Влияние санкций на ключевые отрасли экономики ...
# 1               0  Влияние санкций на ключевые отрасли экономики ...
# 2               1                        Сценарии снятия санкций США
# 3               1                        Сценарии снятия санкций США
# 4               2                            Трансформация автопрома
# 5               2                            Трансформация автопрома
# 6               3                        Авиапром и импортозамещение
# 7               3                        Авиапром и импортозамещение
# 8               4                        Роль МСП в импортозамещении
# 9               4                        Роль МСП в импортозамещении
# 10              5                          Финансовая инфраструктура
# 11              5                          Финансовая инфраструктура
#
#                                    key_moment_comment  \
# 0   Санкции стимулировали развитие отечественного ...
# 1   Санкции стимулировали развитие отечественного ...
# 2   Полная отмена маловероятна; возможны точечные ...
# 3   Полная отмена маловероятна; возможны точечные ...
# 4   Рынок авто стагнирует из-за высоких кредитных ...
# 5   Рынок авто стагнирует из-за высоких кредитных ...
# 6   Авиакомпании инвестируют в российское ПО и зап...
# 7   Авиакомпании инвестируют в российское ПО и зап...
# 8   МСП стали драйвером замещения, но зависимость ...
# 9   МСП стали драйвером замещения, но зависимость ...
# 10  Отмена санкций не восстановит доступ к SWIFT, ...
# 11  Отмена санкций не восстановит доступ к SWIFT, ...
#
#                              aspect  \
# 0     Наиболее пострадавшие отрасли
# 1         Прогнозы аналитиков ЦМАКП
# 2                    Условия отмены
# 3            Политическая мотивация
# 4    Переход на китайские платформы
# 5   Риски возврата западных брендов
# 6                  100% локализация
# 7                 Санкционные риски
# 8            Рост числа предприятий
# 9             Китайская конкуренция
# 10                    СПФС vs SWIFT
# 11                   Цифровой рубль
#
#                                        aspect_comment
# 0   Нефтегазовый сектор, машиностроение, авиастрое...
# 1   В марте 2022 г. прогнозировалось наибольшее вл...
# 2   США снимают санкции только при достижении целе...
# 3   Санкции — инструмент давления. Их смягчение во...
# 4   Заводы в Калининграде, Москве и Калуге перешли...
# 5   Возврат иностранных производителей потребует у...
# 6   Планы по выпуску отечественных самолетов к 202...
# 7   США могут смягчить санкции в обмен на уступки,...
# 8   С 5.8 млн (2022 г.) до 6.3 млн (2023 г.) — мал...
# 9   В легкой промышленности китайские производител...
# 10  Российская система охватывает внутренние плате...
# 11  Пилотный проект ЦБ заморожен из-за запросов уч...
